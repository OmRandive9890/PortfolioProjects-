# %% [markdown]
# **Importing Libraries**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None


# read in the data
df = pd.read_csv(r"C:\Users\omran\Downloads\MovieCorrelations\movies.csv")

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# check for missing data

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col,pct_missing))

# few Nan/missing in budget and gross drop them
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %%
# data types for columns 
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
#removing after decimal values in budget and gross

df = df.dropna() # dropping msssing values 

df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')

df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7652                               The Eight Hundred  Not Rated     Action
# 7653                                      The Quarry          R      Crime
# 7656                                           Tulsa      PG-13     Comedy
# 7658                       Black Wall Street Burning          R      Drama
# 7659                                       I Am Fear  Not Rated     Horror
#
#       year                          released  score      votes  \
# ...

# %%
#creating correct year column
df['Year_correct'] = df['released'].str.extract(pat = '([0-9]{4})').astype(int)
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7652                               The Eight Hundred  Not Rated     Action
# 7653                                      The Quarry          R      Crime
# 7656                                           Tulsa      PG-13     Comedy
# 7658                       Black Wall Street Burning          R      Drama
# 7659                                       I Am Fear  Not Rated     Horror
#
#       year                          released  score      votes  \
# ...

# %%
df = df.sort_values(by=['gross'] , inplace=False , ascending=False)

# %%
# dropping duplicaets 

df = df.drop_duplicates()

# %% [markdown]
# **Correlations**

# %%
#hypothesis
# 1.Budget can have high corelation with gross
# 2.Company might have high corealtion

# %%
# scatter plot of budget vs gross

plt.scatter(x=df['budget'] , y=df['gross'])
plt.title('Budget vs Gross Earnings')
plt.xlabel('Gross Earning (Millions)')
plt.ylabel('Film Budget (Millions)')
plt.show()

# %%
# making regression plot for budget vs gross using seaborn

sns.regplot(x='budget' , y='gross', data=df , scatter_kws={"color":"red"} , line_kws={"color":"blue"})
plt.show()

# %%
# Looking for Correlations 

df.corr(numeric_only=True , method='pearson') # pearson correlation by default if not passed
# Out:
#                   year     score     votes    budget     gross   runtime  \
# year          1.000000  0.102346  0.226895  0.314842  0.264716  0.120676
# score         0.102346  1.000000  0.411931  0.056781  0.188259  0.400574
# votes         0.226895  0.411931  1.000000  0.485301  0.632987  0.309366
# budget        0.314842  0.056781  0.485301  1.000000  0.750562  0.270042
# gross         0.264716  0.188259  0.632987  0.750562  1.000000  0.244942
# runtime       0.120676  0.400574  0.309366  0.270042  0.244942  1.000000
# Year_correct  0.997466  0.109815  0.222317  0.305530  0.257703  0.120370
#
#               Year_correct
# year              0.997466
# score             0.109815
# votes             0.222317
# budget            0.305530
# gross             0.257703
# runtime           0.120370
# Year_correct      1.000000

# %%
# high correlation between budget and Gross

# %% [markdown]
# **Visualitizing the correlation**

# %%
correlation_matrix = df.corr(numeric_only=True , method='pearson')

sns.heatmap(correlation_matrix , annot=True)
plt.title('Correlation matrix for Numeric Features')
plt.xlabel('Numeric Data')
plt.ylabel('Movie Features')
plt.show()
